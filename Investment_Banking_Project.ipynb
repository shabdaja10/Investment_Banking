# %%
import pandas as pd

# %%
data = pd.read_excel('/investment_banking.xlsx')

# %%
data.shape
# Out:
# (753089, 9)

# %%
data.head(3)
# Out:
#   broker_id            city          broker_type  \
# 0    BRXX-1  PLANTATION, FL  Inter-dealer broker
# 1    BRXX-1    BRANFORD, CT  Inter-dealer broker
# 2    BRXX-1   JONESBORO, GA  Inter-dealer broker
#
#                           fund_category email_opened webex_meet sales_call  \
# 0  Emerging-Markets Local-Currency Bond          NaN        NaN        NaN
# 1                             Utilities          NaN        NaN        NaN
# 2               Intermediate Government          NaN        NaN        NaN
#
#    firm_sales  global_sales
# 0      174.62        174.62
# 1        0.00          0.00
# 2        0.00          0.00

# %%
data['broker_id'].nunique()
# Out:
# 1178

# %%
data.isna().sum()
# Out:
# broker_id             0
# city                  0
# broker_type           0
# fund_category         0
# email_opened     434545
# webex_meet       667429
# sales_call       573091
# firm_sales            0
# global_sales          0
# dtype: int64

# %%
(data.isna().sum()/data.shape[0])*100
# Out:
# broker_id         0.000000
# city              0.000000
# broker_type       0.000000
# fund_category     0.000000
# email_opened     57.701679
# webex_meet       88.625514
# sales_call       76.098708
# firm_sales        0.000000
# global_sales      0.000000
# dtype: float64

# %%
data['webex_meet'].unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
data['sales_call'].unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
data['email_opened'].unique()
# Out:
# array([nan, 'Y'], dtype=object)

# %%
# Missing value treatment --> filling nan value with N
data['email_opened'] = data['email_opened'].fillna('N')
data['sales_call'] = data['sales_call'].fillna('N')
data['webex_meet'] = data['webex_meet'].fillna('N')

# %%
data.head(5)
# Out:
#   broker_id               city          broker_type  \
# 0    BRXX-1     PLANTATION, FL  Inter-dealer broker
# 1    BRXX-1       BRANFORD, CT  Inter-dealer broker
# 2    BRXX-1      JONESBORO, GA  Inter-dealer broker
# 3    BRXX-2         VIENNA, VA  Inter-dealer broker
# 4    BRXX-3  CHAGRIN FALLS, OH  full-service broker
#
#                           fund_category email_opened webex_meet sales_call  \
# 0  Emerging-Markets Local-Currency Bond            N          N          N
# 1                             Utilities            N          N          N
# 2               Intermediate Government            N          N          N
# 3               Intermediate Government            Y          N          N
# 4                      Target-Date 2050            Y          N          Y
#
#    firm_sales  global_sales
# 0      174.62        174.62
# 1        0.00          0.00
# 2        0.00          0.00
# 3        0.00      30709.00
# 4        0.00          0.00

# %%
data.isna().sum()
# Out:
# broker_id        0
# city             0
# broker_type      0
# fund_category    0
# email_opened     0
# webex_meet       0
# sales_call       0
# firm_sales       0
# global_sales     0
# dtype: int64

# %%
data.groupby(['broker_type'])[['broker_id']].nunique()
# Out:
#                      broker_id
# broker_type
# Inter-dealer broker       1173
# full-service broker          5

# %%
data['city'].head(5)
# Out:
# 0       PLANTATION, FL
# 1         BRANFORD, CT
# 2        JONESBORO, GA
# 3           VIENNA, VA
# 4    CHAGRIN FALLS, OH
# Name: city, dtype: object

# %%
# city column is splited into city and state
data[['city','state']] = data['city'].str.split(',', n=1, expand=True)

# %%
data.head(5)
# Out:
#   broker_id           city          broker_type  \
# 0    BRXX-1     PLANTATION  Inter-dealer broker
# 1    BRXX-1       BRANFORD  Inter-dealer broker
# 2    BRXX-1      JONESBORO  Inter-dealer broker
# 3    BRXX-2         VIENNA  Inter-dealer broker
# 4    BRXX-3  CHAGRIN FALLS  full-service broker
#
#                           fund_category email_opened webex_meet sales_call  \
# 0  Emerging-Markets Local-Currency Bond            N          N          N
# 1                             Utilities            N          N          N
# 2               Intermediate Government            N          N          N
# 3               Intermediate Government            Y          N          N
# 4                      Target-Date 2050            Y          N          Y
#
#    firm_sales  global_sales state
# 0      174.62        174.62    FL
# 1        0.00          0.00    CT
# 2        0.00          0.00    GA
# 3        0.00      30709.00    VA
# 4        0.00          0.00    OH

# %%
data['state'].head(5)
# Out:
# 0     FL
# 1     CT
# 2     GA
# 3     VA
# 4     OH
# Name: state, dtype: object

# %%
data['state'].unique()
# Out:
# array([' FL', ' CT', ' GA', ' VA', ' OH', ' CA', ' WA', ' MD', ' NJ',
#        ' SC', ' OR', ' NY', ' TX', ' NC', ' KS', ' UT', ' PA', ' AZ',
#        ' TN', ' HI', ' AL', ' OK', ' MA', ' WV', ' NH', ' IN', ' MI',
#        ' ME', ' MN', ' DC', ' MS', ' IL', ' LA', ' CO', ' MO', ' IA',
#        ' ND', ' WI', ' KY', ' ID', ' DE', ' NM', ' RI', ' AR', ' PR',
#        ' WY', ' SD', ' AK', ' MT', ' VT', ' NE', ' NV', ', MD', ', CT',
#        ', WI', ' TN, TN', ', VT', ', CA', ' GU', ' DC, DC'], dtype=object)

# %%
# state is having more then 2 character values i.e whitespace
data[data['state'].str.len() >=3] ['state'].unique()
# Out:
# array([' FL', ' CT', ' GA', ' VA', ' OH', ' CA', ' WA', ' MD', ' NJ',
#        ' SC', ' OR', ' NY', ' TX', ' NC', ' KS', ' UT', ' PA', ' AZ',
#        ' TN', ' HI', ' AL', ' OK', ' MA', ' WV', ' NH', ' IN', ' MI',
#        ' ME', ' MN', ' DC', ' MS', ' IL', ' LA', ' CO', ' MO', ' IA',
#        ' ND', ' WI', ' KY', ' ID', ' DE', ' NM', ' RI', ' AR', ' PR',
#        ' WY', ' SD', ' AK', ' MT', ' VT', ' NE', ' NV', ', MD', ', CT',
#        ', WI', ' TN, TN', ', VT', ', CA', ' GU', ' DC, DC'], dtype=object)

# %%
# Correct the derived column
data['state'] = data['state'].str.replace(' ','')
data['state'] = data['state'].str.replace(',','')
data['state'] = data['state'].str.replace('TNTN', 'TN')
data['state'] = data['state'].str.replace('DCDC', 'DC')

# %%
data['state'].unique()
# Out:
# array(['FL', 'CT', 'GA', 'VA', 'OH', 'CA', 'WA', 'MD', 'NJ', 'SC', 'OR',
#        'NY', 'TX', 'NC', 'KS', 'UT', 'PA', 'AZ', 'TN', 'HI', 'AL', 'OK',
#        'MA', 'WV', 'NH', 'IN', 'MI', 'ME', 'MN', 'DC', 'MS', 'IL', 'LA',
#        'CO', 'MO', 'IA', 'ND', 'WI', 'KY', 'ID', 'DE', 'NM', 'RI', 'AR',
#        'PR', 'WY', 'SD', 'AK', 'MT', 'VT', 'NE', 'NV', 'GU'], dtype=object)

# %%
# check state col is having any numeric value
data['state'].str.isnumeric().sum()
# Out:
# np.int64(0)

# %%
data['city'].head(5)
# Out:
# 0       PLANTATION
# 1         BRANFORD
# 2        JONESBORO
# 3           VIENNA
# 4    CHAGRIN FALLS
# Name: city, dtype: object

# %%
# check number of city col with any numeric value
data['city'].str.isnumeric().sum()
# Out:
# np.int64(37)

# %%
data[data['city'].str.isnumeric()].head(30)
# Out:
#        broker_id   city          broker_type                  fund_category  \
# 12956   BRXX-188  64150  Inter-dealer broker                  Equity Energy
# 31538    BRXX-77  15801  Inter-dealer broker          World Small/Mid Stock
# 45478   BRXX-188  64150  Inter-dealer broker          Emerging Markets Bond
# 95111    BRXX-77  15801  Inter-dealer broker                     World Bond
# 107878  BRXX-188  64150  Inter-dealer broker                Short-Term Bond
# 122236   BRXX-70  95678  Inter-dealer broker  Allocation--70% to 85% Equity
# 143794   BRXX-77  15801  Inter-dealer broker            Foreign Large Blend
# 151921   BRXX-77  15801  Inter-dealer broker                 Corporate Bond
# 158007   BRXX-77  15801  Inter-dealer broker              World Large Stock
# 170498  BRXX-188  64150  Inter-dealer broker            Nontraditional Bond
# 174723  BRXX-188  64150  Inter-dealer broker            Foreign Large Value
# 178474   BRXX-77  15801  Inter-dealer broker            Nontraditional Bond
# 231891  BRXX-188  64150  Inter-dealer broker                High Yield Bond
# 233080  BRXX-188  64150  Inter-dealer broker               World Allocation
# 236546   BRXX-70  95678  Inter-dealer broker                Short-Term Bond
# 239104   BRXX-70  95678  Inter-dealer broker               World Allocation
# 242904   BRXX-70  95678  Inter-dealer broker                      Bank Loan
# 258485   BRXX-77  15801  Inter-dealer broker                    Large Value
# 266507  BRXX-188  64150  Inter-dealer broker                   Large Growth
# 286301   BRXX-70  95678  Inter-dealer broker               Multisector Bond
# 343116   BRXX-70  95678  Inter-dealer broker                High Yield Bond
# 361358   BRXX-77  15801  Inter-dealer broker                   Convertibles
# 384772   BRXX-70  95678  Inter-dealer broker                    Large Blend
# 434361   BRXX-77  15801  Inter-dealer broker                    Small Blend
# 452242   BRXX-70  95678  Inter-dealer broker                    Large Value
# 485769   BRXX-77  15801  Inter-dealer broker  Allocation--50% to 70% Equity
# 527815   BRXX-70  95678  Inter-dealer broker         Intermediate-Term Bond
# 531297   BRXX-77  15801  Inter-dealer broker      Diversified Emerging Mkts
# 536996   BRXX-77  15801  Inter-dealer broker               Multialternative
# 549610   BRXX-77  15801  Inter-dealer broker                 Mid-Cap Growth
#
#        email_opened webex_meet sales_call  firm_sales  global_sales state
# 12956             N          N          N        0.00          0.00    MO
# 31538             N          N          N        0.00       5110.16    PA
# 45478             N          N          N        0.00          0.00    MO
# 95111             N          N          N        0.00          0.00    PA
# 107878            N          N          N        0.00          0.00    MO
# 122236            N          N          N        0.00        670.64    CA
# 143794            N          N          N   160313.60     162621.11    PA
# 151921            N          N          N     1684.01       1684.01    PA
# 158007            N          N          N        0.00       4117.37    PA
# 170498            N          N          N        0.00          0.00    MO
# 174723            N          N          N        0.00          0.00    MO
# 178474            N          N          N      446.01      12786.01    PA
# 231891            N          N          N        0.00          0.00    MO
# 233080            N          N          N        0.00          0.00    MO
# 236546            N          N          N        0.00     692287.00    CA
# 239104            N          N          N        0.00       4500.00    CA
# 242904            N          N          N        0.00      63404.00    CA
# 258485            N          N          N      686.65      12590.98    PA
# 266507            N          N          N        0.00     165100.00    MO
# 286301            N          N          N        0.00     663179.12    CA
# 343116            N          N          N        0.00        947.50    CA
# 361358            N          N          N        0.00          0.00    PA
# 384772            N          N          N        0.00        600.00    CA
# 434361            N          N          N      141.02       1569.25    PA
# 452242            N          N          N        0.00         62.50    CA
# 485769            N          N          N        0.00      16148.94    PA
# 527815            N          N          N        0.00      60875.00    CA
# 531297            N          N          N    21907.99      25197.99    PA
# 536996            N          N          N        0.00          0.00    PA
# 549610            N          N          N       32.99         32.99    PA

# %%
(37/753089)*100
#0.0049% of wrong values in city col
# Out:
# 0.004913097920697288

# %%
# find out the numeric values in city col
data[data['city'].str.isnumeric()]['city'].unique()
# Out:
# array(['64150', '15801', '95678'], dtype=object)

# %%
# replace ZIP code with city name
data['city'] = data['city'].str.replace('64150', 'Riverside')
data['city'] = data['city'].str.replace('15801', 'DuBois')
data['city'] = data['city'].str.replace('95678', 'Roseville')

# %%
data[data['city'].str.isnumeric()]['city'].unique()
# Out:
# array([], dtype=object)

# %%
data['city'].str.isnumeric().sum()
# expected count should 0
# Out:
# np.int64(0)

# %%
data[data['city'].str.isnumeric()].head(5)
# expected result should 0
# Out:
# Empty DataFrame
# Columns: [broker_id, city, broker_type, fund_category, email_opened, webex_meet, sales_call, firm_sales, global_sales, state]
# Index: []

# %%
data['email_opened'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
#cleare evident that there is no more then 2 characters in email_opened col
data[data['email_opened'].str.len() > 1].head(5)
# Out:
# Empty DataFrame
# Columns: [broker_id, city, broker_type, fund_category, email_opened, webex_meet, sales_call, firm_sales, global_sales, state]
# Index: []

# %%
data['email_opened'].str.isnumeric().sum()
# Out:
# np.int64(0)

# %%
# Analysis

# %%
# broker1 transactions
data[data['broker_id'] == 'BRXX-1'].head(5)
# Out:
#    broker_id          city          broker_type  \
# 0     BRXX-1    PLANTATION  Inter-dealer broker
# 1     BRXX-1      BRANFORD  Inter-dealer broker
# 2     BRXX-1     JONESBORO  Inter-dealer broker
# 7     BRXX-1  OWINGS MILLS  Inter-dealer broker
# 13    BRXX-1        AUSTIN  Inter-dealer broker
#
#                            fund_category email_opened webex_meet sales_call  \
# 0   Emerging-Markets Local-Currency Bond            N          N          N
# 1                              Utilities            N          N          N
# 2                Intermediate Government            N          N          N
# 7                      World Large Stock            N          N          N
# 13                Intermediate-Term Bond            N          N          N
#
#     firm_sales  global_sales state
# 0       174.62        174.62    FL
# 1         0.00          0.00    CT
# 2         0.00          0.00    GA
# 7         0.00       4807.68    MD
# 13        0.00        600.00    TX

# %%
# find all the transactions for all the brokers
data.groupby('broker_id')[['firm_sales','global_sales']].sum().head(5)
# Out:
#             firm_sales  global_sales
# broker_id
# BRXX-1     11157673.73  1.066317e+08
# BRXX-10           0.00  7.483650e+05
# BRXX-100     267918.14  8.150361e+06
# BRXX-1000         0.00  0.000000e+00
# BRXX-1001         0.00  1.089745e+06

# %%
data[data['broker_id'] == 'BRXX-1']['firm_sales'].sum()
# Out:
# np.float64(11157673.73)

# %%
data[data['broker_id'] == 'BRXX-1']['global_sales'].sum().astype(int)
# Out:
# np.int64(106631687)

# %%
(11157673.73/106631687)*100
# 10% of sales is purchased from us and 90% is purchased from others
# Out:
# 10.463750545370253

# %%
df = data.groupby('broker_id')[['firm_sales', 'global_sales']].sum()

# %%
df.head(5)
# Out:
#             firm_sales  global_sales
# broker_id
# BRXX-1     11157673.73  1.066317e+08
# BRXX-10           0.00  7.483650e+05
# BRXX-100     267918.14  8.150361e+06
# BRXX-1000         0.00  0.000000e+00
# BRXX-1001         0.00  1.089745e+06

# %%
# create new dataframe loyality_percentage
df['loyality_percentage'] = (df['firm_sales']/df['global_sales'])*100

# %%
df.head(5)
# Out:
#             firm_sales  global_sales  loyality_percentage
# broker_id
# BRXX-1     11157673.73  1.066317e+08            10.463750
# BRXX-10           0.00  7.483650e+05             0.000000
# BRXX-100     267918.14  8.150361e+06             3.287194
# BRXX-1000         0.00  0.000000e+00                  NaN
# BRXX-1001         0.00  1.089745e+06             0.000000

# %%
# sort by loyality_percentage in descending order
df.sort_values('loyality_percentage', ascending=False).head(10)
# Out:
#             firm_sales  global_sales  loyality_percentage
# broker_id
# BRXX-1005        77.23         77.23           100.000000
# BRXX-1019      5571.97       5571.97           100.000000
# BRXX-1036       245.76        245.76           100.000000
# BRXX-498      13042.03      13042.03           100.000000
# BRXX-710      27438.30      27627.97            99.313486
# BRXX-744    4352339.58    4389608.62            99.150971
# BRXX-1121    754618.93     775703.36            97.281895
# BRXX-24    15800032.61   16787455.29            94.118092
# BRXX-945      25429.96      27142.96            93.688971
# BRXX-197    1000213.01    1203312.21            83.121654

# %%
# Expected output
# broker | firm_sales | global_sales | loyality_percentage | loyality_category

# %%
def loyality_check(loc_percent):
  if loc_percent == 100:
      return "Loyal Brokers"
  elif loc_percent >= 85 and loc_percent < 100:
      return "Steadyfast Brokers"
  elif loc_percent >= 50 and loc_percent < 85:
      return "Resonably Devoted Brokers(Moderate)"
  elif loc_percent < 50 and loc_percent > 0:
      return "Less Inclined Brokers"
  elif loc_percent == 0:
      return "Non-Committed Brokers"
  else:
      return "Stagant Brokers"

# %%
df['loyality_percentage'] = pd.to_numeric(df['loyality_percentage'], errors='coerce')

# %%
loyality_check(30)
# Out:
# 'Less Inclined Brokers'

# %%
# create new dataframe loyality_category
df['loyality_category'] = df['loyality_percentage'].apply(loyality_check)

# %%
df.head(5)
# Out:
#             firm_sales  global_sales  loyality_percentage  \
# broker_id
# BRXX-1     11157673.73  1.066317e+08            10.463750
# BRXX-10           0.00  7.483650e+05             0.000000
# BRXX-100     267918.14  8.150361e+06             3.287194
# BRXX-1000         0.00  0.000000e+00                  NaN
# BRXX-1001         0.00  1.089745e+06             0.000000
#
#                loyality_category
# broker_id
# BRXX-1     Less Inclined Brokers
# BRXX-10    Non-Committed Brokers
# BRXX-100   Less Inclined Brokers
# BRXX-1000        Stagant Brokers
# BRXX-1001  Non-Committed Brokers

# %%
# convert brok_id index to column
df['brok_id'] = df.index

# %%
df.head(5)
# Out:
#             firm_sales  global_sales  loyality_percentage  \
# broker_id
# BRXX-1     11157673.73  1.066317e+08            10.463750
# BRXX-10           0.00  7.483650e+05             0.000000
# BRXX-100     267918.14  8.150361e+06             3.287194
# BRXX-1000         0.00  0.000000e+00                  NaN
# BRXX-1001         0.00  1.089745e+06             0.000000
#
#                loyality_category    brok_id
# broker_id
# BRXX-1     Less Inclined Brokers     BRXX-1
# BRXX-10    Non-Committed Brokers    BRXX-10
# BRXX-100   Less Inclined Brokers   BRXX-100
# BRXX-1000        Stagant Brokers  BRXX-1000
# BRXX-1001  Non-Committed Brokers  BRXX-1001

# %%
# find out number of brokers by category
df.groupby('loyality_category')[['brok_id']].count()
# Out:
#                                      brok_id
# loyality_category
# Less Inclined Brokers                    310
# Loyal Brokers                              4
# Non-Committed Brokers                    686
# Resonably Devoted Brokers(Moderate)        7
# Stagant Brokers                          166
# Steadyfast Brokers                         5

# %%
df.groupby('loyality_category')[['brok_id']].count().sort_values('brok_id', ascending=False)
# Out:
#                                      brok_id
# loyality_category
# Non-Committed Brokers                    686
# Less Inclined Brokers                    310
# Stagant Brokers                          166
# Resonably Devoted Brokers(Moderate)        7
# Steadyfast Brokers                         5
# Loyal Brokers                              4

# %%
# the firm is not making good business and is at loss
